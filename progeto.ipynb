# %%
import win32gui
import win32con
import pyautogui
import openpyxl
import pyperclip
from time import sleep
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)
navegador.get('https://cadastro-produtos-devaprender.netlify.app/index.html')

#########################################################
                                                       
hwnd = win32gui.GetForegroundWindow()  # Obtém a janela ativa
win32gui.ShowWindow(hwnd, win32con.SW_MAXIMIZE)  # Maximiza a janela
sleep(1)
pyautogui.hotkey('win','right')
pyautogui.press('enter')

sleep(1)
abrir_planlha = openpyxl.load_workbook('produtos_ficticios.xlsx')
sheet_produtos = abrir_planlha['Produtos']
linhas = sheet_produtos.iter_rows( min_row=2)
sleep(1)
for linha in linhas:
    
    nome_produto =(linha[0].value)
    pyperclip.copy(nome_produto)
    pyautogui.click(1332,335, duration=1)
    pyautogui.hotkey('ctrl','v')
       
    descrisao =(linha[1].value)
    pyperclip.copy(descrisao)
    pyautogui.click(1374,451, duration=1)
    pyautogui.hotkey('ctrl','v')

    categoria =(linha[2].value)
    pyperclip.copy(categoria)
    pyautogui.click(1418,606, duration=1)
    pyautogui.hotkey('ctrl','v')
    
    
    codigo_produto =(linha[3].value)
    pyperclip.copy(codigo_produto)
    pyautogui.click(1415, 706, duration=1)
    pyautogui.hotkey('ctrl','v')
    

    peso =(linha[4].value)
    pyperclip.copy(peso)
    pyautogui.click(1387, 825, duration=1)
    pyautogui.hotkey('ctrl','v')
    

    dimensoes =(linha[5].value)
    pyperclip.copy(dimensoes)
    pyautogui.click(1392, 930, duration=1)
    pyautogui.hotkey('ctrl','v')

    pyautogui.click(1149,1001,duration=1)
    
    # etapa 2
    preco =(linha[6].value)
    pyperclip.copy(preco)
    pyautogui.click(1381, 362, duration=1)
    pyautogui.hotkey('ctrl','v')

    quantidade_estoque =(linha[7].value)
    pyperclip.copy(preco)
    pyautogui.click(1400,468, duration=1)
    pyautogui.hotkey('ctrl','v')

    data_validade =(linha[8].value)
    pyperclip.copy(data_validade)
    pyautogui.click(1377, 575, duration=1)
    pyautogui.hotkey('ctrl','v')

    cor =(linha[9].value)
    pyperclip.copy(cor)
    pyautogui.click(1375, 684, duration=1)
    pyautogui.hotkey('ctrl','v')
    

    tamanho =(linha[10].value)
    pyperclip.copy(tamanho)
    pyautogui.click(1369, 784, duration=1)
    if tamanho == 'Pequeno':
        pyautogui.click(1391, 823,duration=1)
    elif tamanho == 'Médio':
        pyautogui.click(1419, 860,duration=1)
    else:
        pyautogui.click(1344,901,duration=1)
    
    
    material =(linha[11].value)
    pyperclip.copy(material)
    pyautogui.click(1394, 894, duration=1)
    pyautogui.hotkey('ctrl','v')
    pyautogui.click(1168,957,duration=1)
    
    # etapa 3
    frabricante =(linha[12].value)
    pyperclip.copy(frabricante)
    pyautogui.click(1370, 380, duration=1)
    pyautogui.hotkey('ctrl','v')

    pais_origem =(linha[13].value)
    pyperclip.copy(pais_origem)
    pyautogui.click(1358, 490, duration=1)
    pyautogui.hotkey('ctrl','v')

    observaçoes =(linha[14].value)
    pyperclip.copy(observaçoes)
    pyautogui.click(1412, 624, duration=1)
    pyautogui.hotkey('ctrl','v')
    
    codigo_de_barras =(linha[15].value)
    pyperclip.copy(codigo_de_barras)
    pyautogui.click(1367, 763, duration=1)
    pyautogui.hotkey('ctrl','v')

    localizacao =(linha[16].value)
    pyperclip.copy(localizacao)
    pyautogui.click(1370, 875, duration=1)
    pyautogui.hotkey('ctrl','v')

    pyautogui.click(1195,950,duration=1)
    pyautogui.click(1654,231,duration=1)
    pyautogui.click(1516,663,duration=1)
